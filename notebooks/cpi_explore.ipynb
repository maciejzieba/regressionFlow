# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
from pathlib import Path
import numpy as np
import pickle
import matplotlib.pyplot as plt
from PIL import Image
import data_regression_SDD as drs

# %%
ds = drs.SDDData(root_dir="/home/mprzewiezlikowski/mnt/local_truten/sdd/")

# %%
ds = drs.SDDData(root_dir="/home/mprzewiezlikowski/uj/regressionFlow/cpi_generation/cpi/", width=512, height=512)

# %%
len(ds)
# Out:
# 5

# %%
x = ds[0]

# %%
for (i,x) in enumerate(ds):
    print(i)
    break
# Out:
# 0

# %%
one, two = x

# %%
two
# Out:
# array([0.5256868 , 0.52050066])

# %%
for e in one:
    plt.imshow(e)
    plt.show()

# %%
ds = drs.SDDData(root_dir="../../Multimodal-Future-Prediction/CPI/cpi_v2/")

# %%
ds.dataset.load_scenes()

# %%
len(ds.dataset.scenes)
# Out:
# 0

# %%
for x in ds:
    break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-de1331e7ff2c> in <module>
# ----> 1 for x in ds:
#       2     break
#
# ~/uj/regressionFlow/data_regression_SDD.py in __getitem__(self, idx)
#     129     def __getitem__(self, idx):
#     130         if self.split == 'train':
# --> 131             j = np.random.choice(len(self.dataset.scenes), 1)[0]
#     132             scene = self.dataset.scenes[j]
#     133             i = np.random.choice(len(scene.sequences), 1)[0]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
ds_path = Path("/home/mprzewiezlikowski/uj/Multimodal-Future-Prediction/CPI/cpi_train/")

# %%
for i in range(3):
    with (ds_path / f"scene_0000000/-sample00{i}.png" ).open("rb") as f:
        img = pickle.load(f)
    
    plt.imshow(img)
    plt.show()

# %%
with (ds_path / "scene_0000000/002-000000-019-objects.float3").open("rb") as f:
    objs = pickle.load(f)
objs
# Out:
# array([[[301.03530353, 186.10464119,  20.        , 212.13422944,
#          212.43760745,  40.        ]]])

# %%
ds_path / "scene_0000000/-sample000.png"
# Out:
# True

# %%
from IPython import display
from PIL import Image

# %%
display(Image.open("../checkpoints/experiment_regression_flow_CPI_test"))
